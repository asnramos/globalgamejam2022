# %%
# !pip install keplergl

# %%
! jupyter nbextension install --py --sys-prefix keplergl # can be skipped for notebook 5.3 and above
# Out:
# Installing /srv/conda/envs/notebook/lib/python3.7/site-packages/keplergl/static -> keplergl-jupyter
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/keplergl-jupyter/keplergl.html
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/keplergl-jupyter/index.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/keplergl-jupyter/extension.js
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/keplergl-jupyter/extension.js.map
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/keplergl-jupyter/index.js.map
# Up to date: /srv/conda/envs/notebook/share/jupyter/nbextensions/keplergl-jupyter/main.js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable keplergl --py --sys-prefix

# %%
! jupyter nbextension enable --py --sys-prefix keplergl # can be skipped for notebook 5.3 and above
# Out:
# Enabling notebook extension keplergl-jupyter/extension...
#       - Validating: OK

# %%
# Load an empty map
from keplergl import KeplerGl
map_1 = KeplerGl()
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
# Load an empty map
from keplergl import KeplerGl
map_1 = KeplerGl()
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()
